# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# insert oauth token instead of ''
# !python toloka.py '' 4609092 -c
# Out:
# toloka.py:224: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   )['chosen_alg'].agg({'n_showed': 'count', 'different_answers': 'nunique'})
# toloka.py:254: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'honeypotted'].agg({'n_showed': 'count', 'n_wrong': 'sum'})

# %%
df = pd.read_csv('pool_4609092_results.csv', index_col='Unnamed: 0')

# %%
pd.options.display.max_columns = 50
df.head()
# Out:
#    pool_id  infinite_overlap                  created  \
# 0  4609092              True  2019-04-17T17:10:15.105
# 1  4609092             False  2019-04-17T17:10:15.105
# 2  4609092             False  2019-04-17T17:10:15.105
# 3  4609092             False  2019-04-17T17:10:15.105
# 4  4609092             False  2019-04-17T17:10:15.105
#
#                                           image_left  \
# 0  highlightdisk/screenshot_emails/gensim_sentenc...
# 1  highlightdisk/screenshot_emails/tf_idf_custom/...
# 2  highlightdisk/screenshot_emails/tf_idf_custom/...
# 3  highlightdisk/screenshot_emails/random_good/le...
# 4  highlightdisk/screenshot_emails/tf_idf_custom/...
#
#                                          image_right golden  \
# 0  highlightdisk/screenshot_emails/random/letter1...   left
# 1  highlightdisk/screenshot_emails/random_good/le...    NaN
# 2  highlightdisk/screenshot_emails/random_good/le...    NaN
# 3  highlightdisk/screenshot_emails/tf_idf_custom/...    NaN
# 4  highlightdisk/screenshot_emails/random_good/le...    NaN
#
#                                 task_id  overlap submitted  \
# 0  0000465444--5cb756cf139fff0131310fcf      NaN       NaN
# 1  0000465444--5cb756cf139fff0131310fb6     34.0       NaN
# 2  0000465444--5cb756cf139fff0131310fc2     34.0       NaN
# 3  0000465444--5cb756cf139fff0131310fc5     34.0       NaN
# 4  0000465444--5cb756cf139fff0131310fc0     34.0       NaN
#
#                    expired  public_comment accepted solution  \
# 0  2019-04-17T17:10:36.595             NaN      NaN      NaN
# 1  2019-04-17T17:10:36.595             NaN      NaN      NaN
# 2  2019-04-17T17:10:36.595             NaN      NaN      NaN
# 3  2019-04-17T17:10:36.595             NaN      NaN      NaN
# 4  2019-04-17T17:10:36.595             NaN      NaN      NaN
#
#                                      id                         task_suite_id  \
# 0  0000465444--5cb75df79f709c0138f0751a  0000465444--5cb75df79f709c0138f07518
# 1  0000465444--5cb75df79f709c0138f0751a  0000465444--5cb75df79f709c0138f07518
# 2  0000465444--5cb75df79f709c0138f0751a  0000465444--5cb75df79f709c0138f07518
# 3  0000465444--5cb75df79f709c0138f0751a  0000465444--5cb75df79f709c0138f07518
# 4  0000465444--5cb75df79f709c0138f0751a  0000465444--5cb75df79f709c0138f07518
#
#                             user_id   status  reward  mixed  automerged  \
# 0  b8103bf0f7ae254141c5ef1610dd39ff  EXPIRED    0.01   True       False
# 1  b8103bf0f7ae254141c5ef1610dd39ff  EXPIRED    0.01   True       False
# 2  b8103bf0f7ae254141c5ef1610dd39ff  EXPIRED    0.01   True       False
# 3  b8103bf0f7ae254141c5ef1610dd39ff  EXPIRED    0.01   True       False
# 4  b8103bf0f7ae254141c5ef1610dd39ff  EXPIRED    0.01   True       False
#
#                           owner__id  owner__myself          alg_left  \
# 0  83f1ebe16d794ebcccf82b376c12b2c3           True  gensim_sentences
# 1  83f1ebe16d794ebcccf82b376c12b2c3           True     tf_idf_custom
# 2  83f1ebe16d794ebcccf82b376c12b2c3           True     tf_idf_custom
# 3  83f1ebe16d794ebcccf82b376c12b2c3           True       random_good
# 4  83f1ebe16d794ebcccf82b376c12b2c3           True     tf_idf_custom
#
#        alg_right                        algs          task chosen_alg  \
# 0         random    gensim_sentences__random  letter12.png        NaN
# 1    random_good  random_good__tf_idf_custom  letter17.png        NaN
# 2    random_good  random_good__tf_idf_custom   letter4.png        NaN
# 3  tf_idf_custom  random_good__tf_idf_custom   letter6.png        NaN
# 4    random_good  random_good__tf_idf_custom   letter3.png        NaN
#
#    by_inconsistency_blocked_user  honeypotted  by_honeypot_blocked_user
# 0                          False        False                     False
# 1                          False        False                     False
# 2                          False        False                     False
# 3                          False        False                     False
# 4                          False        False                     False

# %%
df.shape
# Out:
# (1995, 30)

# %%
df[~df.golden.isna()].groupby(
        by=['algs']).chosen_alg.value_counts()
# Out:
# algs                       chosen_alg
# gensim_keywords__random    gensim_keywords      35
#                            random               33
# gensim_sentences__random   gensim_sentences     82
#                            random               70
# random__tf_idf_custom      tf_idf_custom        38
#                            random               17
# random__tf_idf_embeddings  tf_idf_embeddings    20
#                            random               13
# Name: chosen_alg, dtype: int64

# %%
df[df.golden.isna()].groupby(
        by=['algs', 'chosen_alg'], 
    )['pool_id'].count()
# Out:
# algs                        chosen_alg
# random_good__tf_idf_custom  random_good      615
#                             tf_idf_custom    617
# Name: pool_id, dtype: int64

# %%
from math import factorial

def c_n_k(n, k):
    return factorial(n) // (factorial(k) * factorial(n - k))

def find_p_val(n1, n2):
#     p_h0 = 0.5
    if n1 < n2:
        n1, n2 = n2, n1
    s = sum(c_n_k(n1 + n2, i) for i in range(n2 + 1))    
    return s / 2**(n1 + n2)

# %%
df['time_taken'] = pd.to_datetime(df.submitted) - pd.to_datetime(df.created)
df['time_taken'].median()
# Out:
# Timedelta('0 days 00:00:45.883500')

# %%
thr_time = pd.datetools.Timedelta(value=50, unit='s') # использовали для определения быстрых ответов на толоке
# Out:
# /home/max/anaconda3/envs/jupkrn/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.core.datetools.Timedelta is deprecated. Please use pandas._libs.tslibs.timedeltas.Timedelta instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### общее распределение ответов

# %%
def plot_barplots(data, color=['b', 'r']):
    plt.figure(figsize=(20,5))
    n = 5
    plt.subplot(1, n, 1)

    cnts = data.groupby(by='chosen_alg')['pool_id'].count()
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Everyone; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 2)
    cnts = data[
        ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out honeypotted; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 3)
    cnts = data[
        ~(data.by_inconsistency_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out inconsistent; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 4)
    cnts = data[
        data.time_taken > thr_time
    ].groupby(by='chosen_alg')['pool_id'].count()
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out too fast; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 5)
    cnts = data[
        (data.time_taken > thr_time)
        & ~(data.by_inconsistency_blocked_user)
        & ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out all "bad"; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    plt.show()

# %%
pairs = df[df.golden.isna()].groupby(
        by=['algs'], 
    )
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    data = pair[1]
    plot_barplots(data)
# Out:
# random_good__tf_idf_custom

# %% [markdown]
# ### распределение ответов по письмам

# %%
a = pair[1]
a.chosen_alg.value_counts(ascending=True)
# Out:
# random_good      615
# tf_idf_custom    617
# Name: chosen_alg, dtype: int64

# %%
df['time_taken'] = pd.to_datetime(df.submitted) - pd.to_datetime(df.created)
df['time_taken'].median()
# Out:
# Timedelta('0 days 00:00:45.883500')

# %%
thr_time = pd.datetools.Timedelta(value=30, unit='s') # использовали для определения быстрых ответов на толоке
# Out:
# /home/max/anaconda3/envs/jupkrn/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.core.datetools.Timedelta is deprecated. Please use pandas._libs.tslibs.timedeltas.Timedelta instead.
#   """Entry point for launching an IPython kernel.

# %%
df.columns
# Out:
# Index(['pool_id', 'infinite_overlap', 'created', 'image_left', 'image_right',
#        'golden', 'task_id', 'overlap', 'submitted', 'expired',
#        'public_comment', 'accepted', 'solution', 'id', 'task_suite_id',
#        'user_id', 'status', 'reward', 'mixed', 'automerged', 'owner__id',
#        'owner__myself', 'alg_left', 'alg_right', 'algs', 'task', 'chosen_alg',
#        'by_inconsistency_blocked_user', 'honeypotted',
#        'by_honeypot_blocked_user', 'time_taken'],
#       dtype='object')

# %%
root_folder = '../screenshot_emails'
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    algnames = sorted(algs.split('__'))
    for task in pair[1].groupby(by='task'):
        taskname = task[1].task.iloc[0]
        print('\t' + taskname)
        paths = ['/'.join([root_folder, algname, taskname]) for algname in algnames]
        imgs = [mpimg.imread(path) for path in paths]
        plt.figure(figsize=(20, 10))
        for i, img in enumerate(imgs):
            plt.subplot(1, len(imgs), i + 1)
            plt.imshow(img)
            plt.axis('off')
        plt.show()
        data = task[1]
        plot_barplots(data)
# Out:
# random_good__tf_idf_custom
# 	letter1.png
# 	letter10.png
# 	letter11.png
# 	letter12.png
# 	letter13.png
# 	letter14.png
# 	letter15.png
# 	letter16.png
# 	letter17.png
# 	letter18.png
# 	letter19.png
# 	letter2.png
# 	letter20.png
# 	letter3.png
# 	letter4.png
# 	letter5.png
# 	letter6.png
# 	letter7.png
# 	letter8.png
# 	letter9.png

# %% [markdown]
# ### К слову о качестве наших алгоритмов и работе ханипотов

# %%
pairs = df[~df.golden.isna()].groupby('algs')
for _, data in pairs:
    algs = data.algs.iloc[0]
    print(algs)
    color = ['b', 'r']
    if algs.split('__')[0] != 'random':
        color.reverse()
    plot_barplots(data, color=color)
# Out:
# gensim_keywords__random
# gensim_sentences__random
# random__tf_idf_custom
# random__tf_idf_embeddings
