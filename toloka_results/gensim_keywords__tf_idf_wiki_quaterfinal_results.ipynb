# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# to save dataframe if it's absent
# to make it work insert oauth token instead of ''
# !python ../util/toloka.py '' 4664187 -b
# Out:
# ../util/toloka.py:214: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   )['chosen_alg'].agg({'n_showed': 'count', 'different_answers': 'nunique'})
# ../util/toloka.py:244: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'honeypotted'].agg({'n_showed': 'count', 'n_wrong': 'sum'})

# %%
df = pd.read_csv('pool_4664187_results.csv', index_col='Unnamed: 0')

# %%
pd.options.display.max_columns = 50
df.head()
# Out:
#    pool_id  overlap  infinite_overlap                  created  \
# 0  4664187     10.0             False  2019-04-22T12:32:06.399
# 1  4664187     10.0             False  2019-04-22T12:32:06.399
# 2  4664187     10.0             False  2019-04-22T12:32:06.399
# 3  4664187     10.0             False  2019-04-22T12:32:06.399
# 4  4664187      NaN              True  2019-04-22T12:32:06.399
#
#                                           image_left  \
# 0  highlightdisk/screenshot_emails/gensim_keyword...
# 1  highlightdisk/screenshot_emails/gensim_keyword...
# 2  highlightdisk/screenshot_emails/gensim_keyword...
# 3  highlightdisk/screenshot_emails/gensim_keyword...
# 4  highlightdisk/screenshot_emails/random/letter8...
#
#                                          image_right golden  \
# 0  highlightdisk/screenshot_emails/tf_idf_wiki/le...    NaN
# 1  highlightdisk/screenshot_emails/tf_idf_wiki/le...    NaN
# 2  highlightdisk/screenshot_emails/tf_idf_wiki/le...    NaN
# 3  highlightdisk/screenshot_emails/tf_idf_wiki/le...    NaN
# 4  highlightdisk/screenshot_emails/tf_idf_embeddi...  right
#
#                                 task_id submitted expired  public_comment  \
# 0  0000472b7b--5cbd9462841a9f012f4721b0       NaN     NaN             NaN
# 1  0000472b7b--5cbd9462841a9f012f4721b2       NaN     NaN             NaN
# 2  0000472b7b--5cbd9462841a9f012f472196       NaN     NaN             NaN
# 3  0000472b7b--5cbd9462841a9f012f4721a2       NaN     NaN             NaN
# 4  0000472b7b--5cbd9462841a9f012f4721c2       NaN     NaN             NaN
#
#   accepted                  skipped solution  \
# 0      NaN  2019-04-22T12:32:27.510      NaN
# 1      NaN  2019-04-22T12:32:27.510      NaN
# 2      NaN  2019-04-22T12:32:27.510      NaN
# 3      NaN  2019-04-22T12:32:27.510      NaN
# 4      NaN  2019-04-22T12:32:27.510      NaN
#
#                                      id                         task_suite_id  \
# 0  0000472b7b--5cbdb4462884b9014aec927c  0000472b7b--5cbdb4462884b9014aec927a
# 1  0000472b7b--5cbdb4462884b9014aec927c  0000472b7b--5cbdb4462884b9014aec927a
# 2  0000472b7b--5cbdb4462884b9014aec927c  0000472b7b--5cbdb4462884b9014aec927a
# 3  0000472b7b--5cbdb4462884b9014aec927c  0000472b7b--5cbdb4462884b9014aec927a
# 4  0000472b7b--5cbdb4462884b9014aec927c  0000472b7b--5cbdb4462884b9014aec927a
#
#                             user_id   status  reward  mixed  automerged  \
# 0  dbb506e75426fc68204a5e0fb717eca2  SKIPPED    0.01   True       False
# 1  dbb506e75426fc68204a5e0fb717eca2  SKIPPED    0.01   True       False
# 2  dbb506e75426fc68204a5e0fb717eca2  SKIPPED    0.01   True       False
# 3  dbb506e75426fc68204a5e0fb717eca2  SKIPPED    0.01   True       False
# 4  dbb506e75426fc68204a5e0fb717eca2  SKIPPED    0.01   True       False
#
#                           owner__id  owner__myself         alg_left  \
# 0  83f1ebe16d794ebcccf82b376c12b2c3           True  gensim_keywords
# 1  83f1ebe16d794ebcccf82b376c12b2c3           True  gensim_keywords
# 2  83f1ebe16d794ebcccf82b376c12b2c3           True  gensim_keywords
# 3  83f1ebe16d794ebcccf82b376c12b2c3           True  gensim_keywords
# 4  83f1ebe16d794ebcccf82b376c12b2c3           True           random
#
#            alg_right                          algs          task chosen_alg  \
# 0        tf_idf_wiki  gensim_keywords__tf_idf_wiki   letter5.png        NaN
# 1        tf_idf_wiki  gensim_keywords__tf_idf_wiki   letter6.png        NaN
# 2        tf_idf_wiki  gensim_keywords__tf_idf_wiki  letter11.png        NaN
# 3        tf_idf_wiki  gensim_keywords__tf_idf_wiki  letter17.png        NaN
# 4  tf_idf_embeddings     random__tf_idf_embeddings   letter8.png        NaN
#
#    by_inconsistency_blocked_user  honeypotted  by_honeypot_blocked_user
# 0                          False        False                     False
# 1                          False        False                     False
# 2                          False        False                     False
# 3                          False        False                     False
# 4                          False        False                     False

# %%
df.shape
# Out:
# (580, 31)

# %%
df[~df.golden.isna()].groupby(
        by=['algs']).chosen_alg.value_counts()
# Out:
# algs                       chosen_alg
# embeddings__random         embeddings           21
#                            random                7
# random__tf_idf_custom      tf_idf_custom        26
#                            random               12
# random__tf_idf_embeddings  tf_idf_embeddings    26
#                            random                8
# Name: chosen_alg, dtype: int64

# %%
df[df.golden.isna()].groupby(
        by=['algs', 'chosen_alg'], 
    )['pool_id'].count()
# Out:
# algs                          chosen_alg
# gensim_keywords__tf_idf_wiki  gensim_keywords     95
#                               tf_idf_wiki        305
# Name: pool_id, dtype: int64

# %%
from math import factorial

def c_n_k(n, k):
    return factorial(n) // (factorial(k) * factorial(n - k))

def find_p_val(n1, n2):
#     p_h0 = 0.5
    if n1 < n2:
        n1, n2 = n2, n1
    s = sum(c_n_k(n1 + n2, i) for i in range(n2 + 1))    
    return s / 2**(n1 + n2)

# %%
df['time_taken'] = pd.to_datetime(df.submitted) - pd.to_datetime(df.created)
df['time_taken'].median()
# Out:
# Timedelta('0 days 00:00:36.074000')

# %%
thr_time = pd.datetools.Timedelta(value=30, unit='s') # использовали для определения быстрых ответов на толоке
# Out:
# /home/max/anaconda3/envs/jupkrn/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.core.datetools.Timedelta is deprecated. Please use pandas._libs.tslibs.timedeltas.Timedelta instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### общее распределение ответов

# %%
def plot_barplots(data, color=['b', 'r']):
    algs = data.algs.iloc[0].split('__')
    plt.figure(figsize=(20,5))
    n = 5
    plt.subplot(1, n, 1)

    cnts = data.groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Everyone; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 2)
    cnts = data[
        ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out honeypotted; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 3)
    cnts = data[
        ~(data.by_inconsistency_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out inconsistent; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 4)
    cnts = data[
        data.time_taken > thr_time
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out too fast; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 5)
    cnts = data[
        (data.time_taken > thr_time)
        & ~(data.by_inconsistency_blocked_user)
        & ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out all "bad"; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    plt.show()

# %%
pairs = df[df.golden.isna()].groupby(
        by=['algs'], 
    )
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    data = pair[1]
    plot_barplots(data)
# Out:
# gensim_keywords__tf_idf_wiki

# %% [markdown]
# ### распределение ответов по письмам

# %%
root_folder = '../screenshot_emails'
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    algnames = sorted(algs.split('__'))
    for task in pair[1].groupby(by='task'):
        taskname = task[1].task.iloc[0]
        print('\t' + taskname)
        paths = ['/'.join([root_folder, algname, taskname]) for algname in algnames]
        imgs = [mpimg.imread(path) for path in paths]
        plt.figure(figsize=(20, 10))
        for i, img in enumerate(imgs):
            plt.subplot(1, len(imgs), i + 1)
            plt.imshow(img)
            plt.axis('off')
        plt.show()
        data = task[1]
        plot_barplots(data)
# Out:
# gensim_keywords__tf_idf_wiki
# 	letter1.png
# 	letter10.png
# 	letter11.png
# 	letter12.png
# 	letter13.png
# 	letter14.png
# 	letter15.png
# 	letter16.png
# 	letter17.png
# 	letter18.png
# 	letter19.png
# 	letter2.png
# 	letter20.png
# 	letter3.png
# 	letter4.png
# 	letter5.png
# 	letter6.png
# 	letter7.png
# 	letter8.png
# 	letter9.png

# %% [markdown]
# ### К слову о качестве наших алгоритмов и работе ханипотов

# %%
pairs = df[~df.golden.isna()].groupby('algs')
for _, data in pairs:
    algs = data.algs.iloc[0]
    print(algs)
    color = ['b', 'r']
    if algs.split('__')[0] != 'random':
        color.reverse()
    plot_barplots(data, color=color)
# Out:
# embeddings__random
# random__tf_idf_custom
# random__tf_idf_embeddings
