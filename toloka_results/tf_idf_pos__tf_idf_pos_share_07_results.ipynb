# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# to save dataframe if it's absent
# to make it work insert oauth token instead of ''
# !python ../util/toloka.py '' 5016225 -b
# Out:
# ../util/toloka.py:214: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   )['chosen_alg'].agg({'n_showed': 'count', 'different_answers': 'nunique'})
# ../util/toloka.py:244: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'honeypotted'].agg({'n_showed': 'count', 'n_wrong': 'sum'})

# %%
df = pd.read_csv('pool_5016225_results.csv', index_col='Unnamed: 0')

# %%
pd.options.display.max_columns = 50
df.head()
# Out:
#    pool_id  overlap  infinite_overlap                  created  \
# 0  5016225     10.0             False  2019-05-20T12:49:32.806
# 1  5016225     10.0             False  2019-05-20T12:49:32.806
# 2  5016225      NaN              True  2019-05-20T12:49:32.806
# 3  5016225     10.0             False  2019-05-20T12:49:32.806
# 4  5016225     10.0             False  2019-05-20T12:49:32.806
#
#                                           image_left  \
# 0  highlightdisk/screenshot_emails/tf_idf_pos/let...
# 1  highlightdisk/screenshot_emails/tf_idf_pos_sha...
# 2  highlightdisk/screenshot_emails/random/letter4...
# 3  highlightdisk/screenshot_emails/tf_idf_pos/let...
# 4  highlightdisk/screenshot_emails/tf_idf_pos/let...
#
#                                          image_right golden  \
# 0  highlightdisk/screenshot_emails/tf_idf_pos_sha...    NaN
# 1  highlightdisk/screenshot_emails/tf_idf_pos/let...    NaN
# 2  highlightdisk/screenshot_emails/tf_idf_pos/let...  right
# 3  highlightdisk/screenshot_emails/tf_idf_pos_sha...    NaN
# 4  highlightdisk/screenshot_emails/tf_idf_pos_sha...    NaN
#
#                                 task_id                submitted expired  \
# 0  00004c8aa1--5ce2a195f621d27e2c9d0764  2019-05-20T12:50:02.879     NaN
# 1  00004c8aa1--5ce2a195f621d27e2c9d076d  2019-05-20T12:50:02.879     NaN
# 2  00004c8aa1--5ce2a195f621d27e2c9d0782  2019-05-20T12:50:02.879     NaN
# 3  00004c8aa1--5ce2a195f621d27e2c9d076a  2019-05-20T12:50:02.879     NaN
# 4  00004c8aa1--5ce2a195f621d27e2c9d0762  2019-05-20T12:50:02.879     NaN
#
#    public_comment                 accepted  skipped solution  \
# 0             NaN  2019-05-20T12:50:02.879      NaN     left
# 1             NaN  2019-05-20T12:50:02.879      NaN     left
# 2             NaN  2019-05-20T12:50:02.879      NaN    right
# 3             NaN  2019-05-20T12:50:02.879      NaN     left
# 4             NaN  2019-05-20T12:50:02.879      NaN     left
#
#                                      id                         task_suite_id  \
# 0  00004c8aa1--5ce2a25c35b8c10124d8a29e  00004c8aa1--5ce2a25c35b8c10124d8a29c
# 1  00004c8aa1--5ce2a25c35b8c10124d8a29e  00004c8aa1--5ce2a25c35b8c10124d8a29c
# 2  00004c8aa1--5ce2a25c35b8c10124d8a29e  00004c8aa1--5ce2a25c35b8c10124d8a29c
# 3  00004c8aa1--5ce2a25c35b8c10124d8a29e  00004c8aa1--5ce2a25c35b8c10124d8a29c
# 4  00004c8aa1--5ce2a25c35b8c10124d8a29e  00004c8aa1--5ce2a25c35b8c10124d8a29c
#
#                             user_id    status  reward  mixed  automerged  \
# 0  59bbdf48e8b98f1af2bfdfd8d1417e1e  ACCEPTED    0.01   True       False
# 1  59bbdf48e8b98f1af2bfdfd8d1417e1e  ACCEPTED    0.01   True       False
# 2  59bbdf48e8b98f1af2bfdfd8d1417e1e  ACCEPTED    0.01   True       False
# 3  59bbdf48e8b98f1af2bfdfd8d1417e1e  ACCEPTED    0.01   True       False
# 4  59bbdf48e8b98f1af2bfdfd8d1417e1e  ACCEPTED    0.01   True       False
#
#                           owner__id  owner__myself             alg_left  \
# 0  83f1ebe16d794ebcccf82b376c12b2c3           True           tf_idf_pos
# 1  83f1ebe16d794ebcccf82b376c12b2c3           True  tf_idf_pos_share_07
# 2  83f1ebe16d794ebcccf82b376c12b2c3           True               random
# 3  83f1ebe16d794ebcccf82b376c12b2c3           True           tf_idf_pos
# 4  83f1ebe16d794ebcccf82b376c12b2c3           True           tf_idf_pos
#
#              alg_right                             algs          task  \
# 0  tf_idf_pos_share_07  tf_idf_pos__tf_idf_pos_share_07  letter17.png
# 1           tf_idf_pos  tf_idf_pos__tf_idf_pos_share_07  letter20.png
# 2           tf_idf_pos               random__tf_idf_pos   letter4.png
# 3  tf_idf_pos_share_07  tf_idf_pos__tf_idf_pos_share_07   letter2.png
# 4  tf_idf_pos_share_07  tf_idf_pos__tf_idf_pos_share_07  letter16.png
#
#             chosen_alg  by_inconsistency_blocked_user  honeypotted  \
# 0           tf_idf_pos                          False        False
# 1  tf_idf_pos_share_07                          False        False
# 2           tf_idf_pos                          False        False
# 3           tf_idf_pos                          False        False
# 4           tf_idf_pos                          False        False
#
#    by_honeypot_blocked_user
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
df.shape
# Out:
# (560, 31)

# %%
df[~df.golden.isna()].groupby(
        by=['algs']).chosen_alg.value_counts()
# Out:
# algs                       chosen_alg
# random__tf_idf_custom      tf_idf_custom        21
#                            random                2
# random__tf_idf_embeddings  tf_idf_embeddings    37
#                            random                9
# random__tf_idf_pos         tf_idf_pos           29
#                            random                2
# Name: chosen_alg, dtype: int64

# %%
df[df.golden.isna()].groupby(
        by=['algs', 'chosen_alg'], 
    )['pool_id'].count()
# Out:
# algs                             chosen_alg
# tf_idf_pos__tf_idf_pos_share_07  tf_idf_pos             214
#                                  tf_idf_pos_share_07    186
# Name: pool_id, dtype: int64

# %%
from math import factorial

def c_n_k(n, k):
    return factorial(n) // (factorial(k) * factorial(n - k))

def find_p_val(n1, n2):
#     p_h0 = 0.5
    if abs(n1 - n2) <= 1:
        return 1.
    if n1 < n2:
        n1, n2 = n2, n1
    s = sum(c_n_k(n1 + n2, i) for i in range(n2 + 1))    
    return 2 * s / 2**(n1 + n2)

# %%
df['time_taken'] = pd.to_datetime(df.submitted) - pd.to_datetime(df.created)
df['time_taken'].median()
# Out:
# Timedelta('0 days 00:00:38.623000')

# %%
thr_time = pd.datetools.Timedelta(value=30, unit='s') # использовали для определения быстрых ответов на толоке
# Out:
# /home/max/anaconda3/envs/jupkrn/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.core.datetools.Timedelta is deprecated. Please use pandas._libs.tslibs.timedeltas.Timedelta instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### общее распределение ответов

# %%
def plot_barplots(data, color=['b', 'r']):
    algs = data.algs.iloc[0].split('__')
    plt.figure(figsize=(20,5))
    n = 5
    plt.subplot(1, n, 1)

    cnts = data.groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Everyone; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 2)
    cnts = data[
        ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out honeypotted; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 3)
    cnts = data[
        ~(data.by_inconsistency_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out inconsistent; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 4)
    cnts = data[
        data.time_taken > thr_time
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out too fast; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    
    plt.subplot(1, n, 5)
    cnts = data[
        (data.time_taken > thr_time)
        & ~(data.by_inconsistency_blocked_user)
        & ~(data.by_honeypot_blocked_user)
    ].groupby(by='chosen_alg')['pool_id'].count()
    cnts = pd.Series(cnts, index=algs).fillna(0).astype('int')
    pval = find_p_val(*cnts)
    plt.bar(cnts.index, cnts, color=color)
    plt.title(f'Filter out all "bad"; \n{"-".join(map(str, cnts))}; p-val={pval:.5f}')
    plt.show()

# %%
pairs = df[df.golden.isna()].groupby(
        by=['algs'], 
    )
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    data = pair[1]
    plot_barplots(data)
# Out:
# tf_idf_pos__tf_idf_pos_share_07

# %% [markdown]
# ### распределение ответов по письмам

# %%
root_folder = '../screenshot_emails'
for pair in pairs:
    algs = pair[1].algs.iloc[0]
    print(algs)
    algnames = sorted(algs.split('__'))
    for task in pair[1].groupby(by='task'):
        taskname = task[1].task.iloc[0]
        print('\t' + taskname)
        paths = ['/'.join([root_folder, algname, taskname]) for algname in algnames]
        imgs = [mpimg.imread(path) for path in paths]
        plt.figure(figsize=(20, 10))
        for i, img in enumerate(imgs):
            plt.subplot(1, len(imgs), i + 1)
            plt.imshow(img)
            plt.axis('off')
        plt.show()
        data = task[1]
        plot_barplots(data)
# Out:
# tf_idf_pos__tf_idf_pos_share_07
# 	letter1.png
# 	letter10.png
# 	letter11.png
# 	letter12.png
# 	letter13.png
# 	letter14.png
# 	letter15.png
# 	letter16.png
# 	letter17.png
# 	letter18.png
# 	letter19.png
# 	letter2.png
# 	letter20.png
# 	letter3.png
# 	letter4.png
# 	letter5.png
# 	letter6.png
# 	letter7.png
# 	letter8.png
# 	letter9.png

# %% [markdown]
# ### К слову о качестве наших алгоритмов и работе ханипотов

# %%
pairs = df[~df.golden.isna()].groupby('algs')
for _, data in pairs:
    algs = data.algs.iloc[0]
    print(algs)
    color = ['b', 'r']
    if algs.split('__')[0] != 'random':
        color.reverse()
    plot_barplots(data, color=color)
# Out:
# random__tf_idf_custom
# random__tf_idf_embeddings
# random__tf_idf_pos
